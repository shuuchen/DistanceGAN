# %%
import os
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# !ls 'results/syn2real/distancegan/'
# Out:
# 0.0

# %%
data_dir = 'results/syn2real/distancegan/0.0/'
files = os.listdir(data_dir)

# %%
files[:]
# Out:
# ['403.B.jpg',
#  '360.A.jpg',
#  '187.A.jpg',
#  '552.A.jpg',
#  '155.AB.jpg',
#  '320.A.jpg',
#  '185.A.jpg',
#  '35.AB.jpg',
#  '361.AB.jpg',
#  '393.B.jpg',
#  '159.A.jpg',
#  '476.B.jpg',
#  '233.BA.jpg',
#  '20.AB.jpg',
#  '94.B.jpg',
#  '223.BA.jpg',
#  '353.B.jpg',
#  '377.AB.jpg',
#  '134.B.jpg',
#  '544.B.jpg',
#  '100.BA.jpg',
#  '215.A.jpg',
#  '563.A.jpg',
#  '419.A.jpg',
#  '138.A.jpg',
#  '352.AB.jpg',
#  '75.B.jpg',
#  '178.A.jpg',
#  '434.B.jpg',
#  '355.A.jpg',
#  '21.A.jpg',
#  '179.A.jpg',
#  '140.A.jpg',
#  '209.BA.jpg',
#  '414.AB.jpg',
#  '109.B.jpg',
#  '332.BA.jpg',
#  '88.A.jpg',
#  '28.AB.jpg',
#  '400.BA.jpg',
#  '514.AB.jpg',
#  '235.B.jpg',
#  '419.AB.jpg',
#  '46.BA.jpg',
#  '80.B.jpg',
#  '70.B.jpg',
#  '183.BA.jpg',
#  '545.B.jpg',
#  '399.B.jpg',
#  '387.B.jpg',
#  '547.BA.jpg',
#  '113.A.jpg',
#  '199.AB.jpg',
#  '294.B.jpg',
#  '173.B.jpg',
#  '344.A.jpg',
#  '260.A.jpg',
#  '474.AB.jpg',
#  '113.B.jpg',
#  '455.BA.jpg',
#  '470.A.jpg',
# ...

# %%
for f in files[:5]:
    
    f_name = f.split('.')[0]
    print(f)
    
    plt.figure(figsize=(15,5))
    
    plt.subplot(131)
    arr = cv2.imread(os.path.join(data_dir, f'{f_name}.A.jpg'))
    plt.imshow(arr)
    
    plt.subplot(132)
    arr = cv2.imread(os.path.join(data_dir, f'{f_name}.AB.jpg'))
    plt.imshow(arr)
    
    plt.subplot(133)
    arr = cv2.imread(os.path.join(data_dir, f'{f_name}.B.jpg'))
    plt.imshow(arr)
    
    plt.show()
# Out:
# 403.B.jpg
# 360.A.jpg
# 187.A.jpg
# 552.A.jpg
# 155.AB.jpg
