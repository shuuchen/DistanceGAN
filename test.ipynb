# %%
import os
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data_dir = 'results/edges2handbags/distancegan/2.0/'
files = os.listdir(data_dir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-87ad76f2e719> in <module>()
#       1 data_dir = 'results/edges2handbags/distancegan/2.0/'
# ----> 2 files = os.listdir(data_dir)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/edges2handbags/distancegan/2.0/'

# %%
files[:10]
# Out:
# ['187.A.jpg',
#  '155.AB.jpg',
#  '185.A.jpg',
#  '35.AB.jpg',
#  '159.A.jpg',
#  '20.AB.jpg',
#  '94.B.jpg',
#  '134.B.jpg',
#  '100.BA.jpg',
#  '138.A.jpg']

# %%
for f in files[:5]:
    
    f_name = f.split('.')[0]
    print(f)
    
    plt.figure(figsize=(15,5))
    
    plt.subplot(131)
    arr = cv2.imread(os.path.join(data_dir, f'{f_name}.A.jpg'))
    plt.imshow(arr)
    
    plt.subplot(132)
    arr = cv2.imread(os.path.join(data_dir, f'{f_name}.AB.jpg'))
    plt.imshow(arr)
    
    plt.subplot(133)
    arr = cv2.imread(os.path.join(data_dir, f'{f_name}.B.jpg'))
    plt.imshow(arr)
    
    plt.show()
# Out:
# 187.A.jpg
# 155.AB.jpg
# 185.A.jpg
# 35.AB.jpg
# 159.A.jpg
